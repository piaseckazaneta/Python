# %% [markdown]
# <a href="https://colab.research.google.com/github/piaseckazaneta/Python/blob/main/Mini_projekt_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# WSTĘP
#
# Tutaj umieścić opis projektu, źródła danych i cel projektu

# %% [markdown]
# 1. IMPORT BIBLIOTEK

# %%
import pandas as pd

from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. WCZYTANIE DANYCH

# %%
# Ścieżki do dysku google
storm_events_details = "/content/drive/MyDrive/Projekt_Python_2026/StormEvents_details_2025.csv"
storm_events_locations = "/content/drive/MyDrive/Projekt_Python_2026/StormEvents_locations_2025.csv"
storm_events_fatalities = "/content/drive/MyDrive/Projekt_Python_2026/StormEvents_fatalities_2025.csv"

# Wczytanie danych
df_details = pd.read_csv(storm_events_details)
df_locations = pd.read_csv(storm_events_locations)
df_fatalities = pd.read_csv(storm_events_fatalities)

# %% [markdown]
# 3. PRZEGLĄD DANYCH

# %% [markdown]
# Analiza wzrokowa danych

# %%
df_details.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202503         31        1104         202503       31      1106
# 1           202503         30        1552         202503       30      1555
# 2           202501          5        1800         202501        6      2227
# 3           202501          3        1300         202501        3      1900
# 4           202501          3        1300         202501        3      1900
#
#    EPISODE_ID  EVENT_ID     STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      201366   1252415   GEORGIA          13  ...       2.22           W
# 1      200337   1241136  MICHIGAN          26  ...       1.47         NNE
# 2      197733   1222851  VIRGINIA          51  ...        NaN         NaN
# 3      197761   1223112  MARYLAND          24  ...        NaN         NaN
# 4      197761   1223113  MARYLAND          24  ...        NaN         NaN
#
#   END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT END_LON  \
# 0         TYUS   33.4757    -85.238  33.4757 -85.238
# 1  EDWARDSBURG   41.7900    -86.100  41.8200 -86.070
# 2          NaN       NaN        NaN      NaN     NaN
# 3          NaN       NaN        NaN      NaN     NaN
# 4          NaN       NaN        NaN      NaN     NaN
#
#                                    EPISODE_NARRATIVE  \
# 0  A cold-front initiated a line of thunderstorms...
# 1  A cold front pushed into the area during the a...
# 2  An area of low pressure tracked across souther...
# 3  An area of low pressure moved off into New Eng...
# 4  An area of low pressure moved off into New Eng...
#
#                                      EVENT_NARRATIVE DATA_SOURCE
# 0  Tree down at the intersection of highway 5 and...         CSV
# 1  A brief EF-1 tornado was confirmed in Edwardsb...         CSV
# 2                                                NaN         CSV
# 3                                                NaN         CSV
# 4                                                NaN         CSV
#
# [5 rows x 51 columns]

# %%
df_fatalities.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         202512        4         0        60389   1296292             I
# 1         202512        1         0        60391   1296789             I
# 2         202512        3         0        60393   1297305             D
# 3         202512       25         0        60553   1298352             I
# 4         202512       26         0        60562   1298509             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION
# 0  12/04/2025 00:00:00          40.0            M  Vehicle/Towed Trailer
# 1  12/01/2025 00:00:00          35.0            F                Boating
# 2  12/03/2025 00:00:00          32.0            M               In Water
# 3  12/25/2025 00:00:00          75.0            F  Vehicle/Towed Trailer
# 4  12/26/2025 00:00:00          44.0            M               In Water

# %%
df_locations.head()
# Out:
#    YEARMONTH  EPISODE_ID  EVENT_ID  LOCATION_INDEX  RANGE AZIMUTH  \
# 0     202508      204641   1287936               2   3.54     SSE
# 1     202508      203789   1269348               1   2.90       E
# 2     202508      203789   1269349               1   0.80     WSW
# 3     202508      204597   1288676               4   1.45     WSW
# 4     202508      204597   1288677               1   1.79      NW
#
#                LOCATION  LATITUDE  LONGITUDE     LAT2     LON2
# 0          SINKING COVE   35.0015   -85.9601     3590  8557606
# 1          BLEASES XRDS   34.0440   -81.7699   342640  8146194
# 2               DOUGLAS   34.6637   -80.8118  3439822  8048708
# 3            HUNTSVILLE   34.7237   -86.6444  3443422  8638664
# 4  FT PAYNE ISBELL ARPT   34.4900   -85.7400  3429400  8544400

# %% [markdown]
# Wyświetlenie wszystkich atrybutów każdej tabeli

# %%
df_details.columns.to_list()
# Out:
# ['BEGIN_YEARMONTH',
#  'BEGIN_DAY',
#  'BEGIN_TIME',
#  'END_YEARMONTH',
#  'END_DAY',
#  'END_TIME',
#  'EPISODE_ID',
#  'EVENT_ID',
#  'STATE',
#  'STATE_FIPS',
#  'YEAR',
#  'MONTH_NAME',
#  'EVENT_TYPE',
#  'CZ_TYPE',
#  'CZ_FIPS',
#  'CZ_NAME',
#  'WFO',
#  'BEGIN_DATE_TIME',
#  'CZ_TIMEZONE',
#  'END_DATE_TIME',
#  'INJURIES_DIRECT',
#  'INJURIES_INDIRECT',
#  'DEATHS_DIRECT',
#  'DEATHS_INDIRECT',
#  'DAMAGE_PROPERTY',
#  'DAMAGE_CROPS',
#  'SOURCE',
#  'MAGNITUDE',
#  'MAGNITUDE_TYPE',
#  'FLOOD_CAUSE',
#  'CATEGORY',
#  'TOR_F_SCALE',
#  'TOR_LENGTH',
#  'TOR_WIDTH',
#  'TOR_OTHER_WFO',
#  'TOR_OTHER_CZ_STATE',
#  'TOR_OTHER_CZ_FIPS',
#  'TOR_OTHER_CZ_NAME',
#  'BEGIN_RANGE',
#  'BEGIN_AZIMUTH',
#  'BEGIN_LOCATION',
#  'END_RANGE',
#  'END_AZIMUTH',
#  'END_LOCATION',
#  'BEGIN_LAT',
#  'BEGIN_LON',
#  'END_LAT',
#  'END_LON',
#  'EPISODE_NARRATIVE',
#  'EVENT_NARRATIVE',
#  'DATA_SOURCE']

# %%
df_fatalities.columns.to_list()
# Out:
# ['FAT_YEARMONTH',
#  'FAT_DAY',
#  'FAT_TIME',
#  'FATALITY_ID',
#  'EVENT_ID',
#  'FATALITY_TYPE',
#  'FATALITY_DATE',
#  'FATALITY_AGE',
#  'FATALITY_SEX',
#  'FATALITY_LOCATION']

# %%
df_locations.columns.to_list()
# Out:
# ['YEARMONTH',
#  'EPISODE_ID',
#  'EVENT_ID',
#  'LOCATION_INDEX',
#  'RANGE',
#  'AZIMUTH',
#  'LOCATION',
#  'LATITUDE',
#  'LONGITUDE',
#  'LAT2',
#  'LON2']

# %% [markdown]
# Sprawdzenie rozmiarów tabel i typów kolumn

# %%
df_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72241 entries, 0 to 72240
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     72241 non-null  int64
#  1   BEGIN_DAY           72241 non-null  int64
#  2   BEGIN_TIME          72241 non-null  int64
#  3   END_YEARMONTH       72241 non-null  int64
#  4   END_DAY             72241 non-null  int64
#  5   END_TIME            72241 non-null  int64
#  6   EPISODE_ID          72241 non-null  int64
#  7   EVENT_ID            72241 non-null  int64
#  8   STATE               72241 non-null  object
#  9   STATE_FIPS          72241 non-null  int64
#  10  YEAR                72241 non-null  int64
#  11  MONTH_NAME          72241 non-null  object
#  12  EVENT_TYPE          72241 non-null  object
#  13  CZ_TYPE             72241 non-null  object
#  14  CZ_FIPS             72241 non-null  int64
#  15  CZ_NAME             72241 non-null  object
#  16  WFO                 72241 non-null  object
#  17  BEGIN_DATE_TIME     72241 non-null  object
#  18  CZ_TIMEZONE         72241 non-null  object
#  19  END_DATE_TIME       72241 non-null  object
#  20  INJURIES_DIRECT     72241 non-null  int64
#  21  INJURIES_INDIRECT   72241 non-null  int64
#  22  DEATHS_DIRECT       72241 non-null  int64
#  23  DEATHS_INDIRECT     72241 non-null  int64
#  24  DAMAGE_PROPERTY     55842 non-null  object
#  25  DAMAGE_CROPS        55095 non-null  object
#  26  SOURCE              72241 non-null  object
#  27  MAGNITUDE           38971 non-null  float64
#  28  MAGNITUDE_TYPE      29741 non-null  object
#  29  FLOOD_CAUSE         7817 non-null   object
#  30  CATEGORY            0 non-null      float64
#  31  TOR_F_SCALE         1591 non-null   object
#  32  TOR_LENGTH          1591 non-null   float64
#  33  TOR_WIDTH           1591 non-null   float64
#  34  TOR_OTHER_WFO       282 non-null    object
#  35  TOR_OTHER_CZ_STATE  282 non-null    object
#  36  TOR_OTHER_CZ_FIPS   282 non-null    float64
#  37  TOR_OTHER_CZ_NAME   282 non-null    object
#  38  BEGIN_RANGE         43917 non-null  float64
#  39  BEGIN_AZIMUTH       43917 non-null  object
#  40  BEGIN_LOCATION      43917 non-null  object
#  41  END_RANGE           43917 non-null  float64
#  42  END_AZIMUTH         43917 non-null  object
#  43  END_LOCATION        43917 non-null  object
#  44  BEGIN_LAT           43917 non-null  float64
#  45  BEGIN_LON           43917 non-null  float64
#  46  END_LAT             43917 non-null  float64
#  47  END_LON             43917 non-null  float64
#  48  EPISODE_NARRATIVE   72241 non-null  object
#  49  EVENT_NARRATIVE     61496 non-null  object
#  50  DATA_SOURCE         72241 non-null  object
# dtypes: float64(11), int64(15), object(25)
# memory usage: 28.1+ MB

# %%
df_details.shape
# Out:
# (72241, 51)

# %%
df_fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FAT_YEARMONTH      895 non-null    int64
#  1   FAT_DAY            895 non-null    int64
#  2   FAT_TIME           895 non-null    int64
#  3   FATALITY_ID        895 non-null    int64
#  4   EVENT_ID           895 non-null    int64
#  5   FATALITY_TYPE      895 non-null    object
#  6   FATALITY_DATE      895 non-null    object
#  7   FATALITY_AGE       743 non-null    float64
#  8   FATALITY_SEX       785 non-null    object
#  9   FATALITY_LOCATION  895 non-null    object
# dtypes: float64(1), int64(5), object(4)
# memory usage: 70.1+ KB

# %%
df_fatalities.shape
# Out:
# (895, 10)

# %%
df_locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51870 entries, 0 to 51869
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YEARMONTH       51870 non-null  int64
#  1   EPISODE_ID      51870 non-null  int64
#  2   EVENT_ID        51870 non-null  int64
#  3   LOCATION_INDEX  51870 non-null  int64
#  4   RANGE           51870 non-null  float64
#  5   AZIMUTH         51870 non-null  object
#  6   LOCATION        51870 non-null  object
#  7   LATITUDE        51870 non-null  float64
#  8   LONGITUDE       51870 non-null  float64
#  9   LAT2            51870 non-null  int64
#  10  LON2            51870 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 4.4+ MB

# %%
df_locations.shape
# Out:
# (51870, 11)

# %% [markdown]
# Sprawdzenie braków w danych

# %%
df_details.isnull().sum()
# Out:
# BEGIN_YEARMONTH           0
# BEGIN_DAY                 0
# BEGIN_TIME                0
# END_YEARMONTH             0
# END_DAY                   0
# END_TIME                  0
# EPISODE_ID                0
# EVENT_ID                  0
# STATE                     0
# STATE_FIPS                0
# YEAR                      0
# MONTH_NAME                0
# EVENT_TYPE                0
# CZ_TYPE                   0
# CZ_FIPS                   0
# CZ_NAME                   0
# WFO                       0
# BEGIN_DATE_TIME           0
# CZ_TIMEZONE               0
# END_DATE_TIME             0
# INJURIES_DIRECT           0
# INJURIES_INDIRECT         0
# DEATHS_DIRECT             0
# DEATHS_INDIRECT           0
# DAMAGE_PROPERTY       16399
# DAMAGE_CROPS          17146
# SOURCE                    0
# MAGNITUDE             33270
# MAGNITUDE_TYPE        42500
# FLOOD_CAUSE           64424
# CATEGORY              72241
# TOR_F_SCALE           70650
# TOR_LENGTH            70650
# TOR_WIDTH             70650
# TOR_OTHER_WFO         71959
# TOR_OTHER_CZ_STATE    71959
# TOR_OTHER_CZ_FIPS     71959
# TOR_OTHER_CZ_NAME     71959
# BEGIN_RANGE           28324
# BEGIN_AZIMUTH         28324
# BEGIN_LOCATION        28324
# END_RANGE             28324
# END_AZIMUTH           28324
# END_LOCATION          28324
# BEGIN_LAT             28324
# BEGIN_LON             28324
# END_LAT               28324
# END_LON               28324
# EPISODE_NARRATIVE         0
# EVENT_NARRATIVE       10745
# DATA_SOURCE               0
# dtype: int64

# %%
df_fatalities.isnull().sum()
# Out:
# FAT_YEARMONTH          0
# FAT_DAY                0
# FAT_TIME               0
# FATALITY_ID            0
# EVENT_ID               0
# FATALITY_TYPE          0
# FATALITY_DATE          0
# FATALITY_AGE         152
# FATALITY_SEX         110
# FATALITY_LOCATION      0
# dtype: int64

# %%
df_locations.isnull().sum()
# Out:
# YEARMONTH         0
# EPISODE_ID        0
# EVENT_ID          0
# LOCATION_INDEX    0
# RANGE             0
# AZIMUTH           0
# LOCATION          0
# LATITUDE          0
# LONGITUDE         0
# LAT2              0
# LON2              0
# dtype: int64

# %% [markdown]
# Sprawdzenie pełnej listy zjawisk, jakie wystąpiły.

# %%
df_details['EVENT_TYPE'].unique()
# Out:
# array(['Thunderstorm Wind', 'Tornado', 'Winter Storm', 'Winter Weather',
#        'High Wind', 'Extreme Cold/Wind Chill', 'Hail', 'Flash Flood',
#        'Blizzard', 'Strong Wind', 'Heavy Snow', 'Flood',
#        'Marine High Wind', 'Excessive Heat', 'Marine Thunderstorm Wind',
#        'Marine Hail', 'Frost/Freeze', 'Sneakerwave', 'Drought',
#        'Funnel Cloud', 'Heavy Rain', 'Heat', 'Wildfire', 'Dust Storm',
#        'Debris Flow', 'Cold/Wind Chill', 'Rip Current', 'Waterspout',
#        'Coastal Flood', 'Lightning', 'Avalanche', 'High Surf',
#        'Lake-Effect Snow', 'Dense Fog', 'Ice Storm', 'Sleet',
#        'Astronomical Low Tide', 'Marine Strong Wind', 'Freezing Fog',
#        'Marine Dense Fog', 'Marine Tropical Storm', 'Tropical Storm',
#        'Tsunami', 'Seiche', 'Tropical Depression', 'Storm Surge/Tide',
#        'Lakeshore Flood', 'Dust Devil'], dtype=object)

# %% [markdown]
# SELEKCJA ATRYBUTÓW

# %% [markdown]
# Zmiana nazw kolumn w df-ach na małe litery

# %%
df_details.columns = df_details.columns.str.lower()
df_fatalities.columns = df_fatalities.columns.str.lower()
df_locations.columns = df_locations.columns.str.lower()

# %% [markdown]
# Selekcja zmiennych do analiz

# %%
df_details_analysis = df_details[["event_id", "state", "event_type", "begin_date_time", "damage_property", "damage_crops", "tor_f_scale", "tor_length", "tor_width"]]

# %%
df_fatalities_analysis = df_fatalities[["event_id", "fatality_age", "fatality_sex", "fatality_location"]]

# %%
df_locations_analysis = df_locations[["event_id", "latitude", "longitude"]]

# %% [markdown]
# KONWERSJA DANYCH
#
# Cel: Naprawa i ujednolicenie formatów

# %% [markdown]
# Konwersja dat
#
# Konwersja kolumny "begin_date_time" z df_details_analysis

# %%
df_details_analysis["begin_date_time"] = pd.to_datetime(df_details_analysis["begin_date_time"])
# Out:
# /tmp/ipykernel_9179/2334216105.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_details_analysis["begin_date_time"] = pd.to_datetime(df_details_analysis["begin_date_time"])
# /tmp/ipykernel_9179/2334216105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_details_analysis["begin_date_time"] = pd.to_datetime(df_details_analysis["begin_date_time"])

# %% [markdown]
# Wyciągnięcie z daty nowych kolumn: month (do analizy sezonowej) oraz hour (do analizy porowej)

# %%
df_details_analysis["begin_date_time"]
# Out:
# 0       2025-03-31 11:04:00
# 1       2025-03-30 15:52:00
# 2       2025-01-05 18:00:00
# 3       2025-01-03 13:00:00
# 4       2025-01-03 13:00:00
#                 ...
# 72236   2025-09-16 14:53:00
# 72237   2025-09-16 14:54:00
# 72238   2025-09-09 16:58:00
# 72239   2025-09-09 19:32:00
# 72240   2025-09-09 18:58:00
# Name: begin_date_time, Length: 72241, dtype: datetime64[ns]

# %%
month = df_details_analysis["begin_date_time"].dt.month

# %%
print(month)
# Out:
# 0        3
# 1        3
# 2        1
# 3        1
# 4        1
#         ..
# 72236    9
# 72237    9
# 72238    9
# 72239    9
# 72240    9
# Name: begin_date_time, Length: 72241, dtype: int32

# %%
hour = df_details_analysis["begin_date_time"].dt.hour

# %%
print(hour)
# Out:
# 0        11
# 1        15
# 2        18
# 3        13
# 4        13
#          ..
# 72236    14
# 72237    14
# 72238    16
# 72239    19
# 72240    18
# Name: begin_date_time, Length: 72241, dtype: int32
