# %% [markdown]
# <a href="https://colab.research.google.com/github/piaseckazaneta/Python/blob/main/Mediana%20z%20kurs%C3%B3w.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

students_sql = {"anna kowalska":[6,7,8,7],"piotr nowak":[5,6,7,6],"monika mazur":[8,7,8,8],"jan zielinski":[3,4,5,4],"pawel krawczyk":[7,6,7,8],"kasia lis":[6,7,6,7],"tomasz wojcik":[4,5,6,5],"agnieszka dabrowska":[7,7,6,7],"michal lewandowski":[5,4,6,5],"karolina krupa":[8,8,7,8],"lukasz wojciechowski":[6,6,7,7],"ola kaminska":[7,6,7,7],"bartosz sikora":[4,5,4,5],"patrycja adamska":[6,7,8,7],"kamil piotrowski":[5,6,5,6]}

students_python = {"anna kowalska":[9,10,10,9],"piotr nowak":[8,9,8,9],"monika mazur":[10,10,10,10],"pawel krawczyk":[9,9,10,9],"kasia lis":[9,9,8,9],"tomasz wojcik":[7,8,9,8],"agnieszka dabrowska":[10,9,10,10],"michal lewandowski":[8,8,9,8],"karolina krupa":[10,10,9,10],"lukasz wojciechowski":[9,9,8,9],"ola kaminska":[9,10,9,9],"daniel czajka":[6,7,7,6],"natalia wrobel":[10,9,9,10],"katarzyna grabowska":[8,9,8,9],"mateusz kaczmarek":[7,8,7,8]}

sql_median = np.median(list(students_sql.values()))
print(sql_median)

python_median = np.median(list(students_python.values()))
print(python_median)

course = None
if sql_median > python_median:
    course = 'sql'
else:
    course = 'python'


print(course)
# Out:
# 6.0
# 9.0
# python

# %%
list(students_python.values())
# Out:
# [[9, 10, 10, 9],
#  [8, 9, 8, 9],
#  [10, 10, 10, 10],
#  [9, 9, 10, 9],
#  [9, 9, 8, 9],
#  [7, 8, 9, 8],
#  [10, 9, 10, 10],
#  [8, 8, 9, 8],
#  [10, 10, 9, 10],
#  [9, 9, 8, 9],
#  [9, 10, 9, 9],
#  [6, 7, 7, 6],
#  [10, 9, 9, 10],
#  [8, 9, 8, 9],
#  [7, 8, 7, 8]]

# %% [markdown]
# Aby wyliczyc medianę z wartości występujących w słowniku, trzeba wyodrębnić wartości za pomocą listy - list, czyli list(students_sql.values()). Otrzymuje się zagnieżdzone listy wartości, z których można juz wyliczyć medianę.
