# %% [markdown]
# <a href="https://colab.research.google.com/github/piaseckazaneta/Python/blob/main/Najmniejsza%20liczba%20parzysta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [246, 361, 118, 521, 142, 409, 304, 189, 534, 278, 431, 372, 167, 508, 135, 396, 455, 317, 208, 468, 221, 291, 418, 479, 101, 339, 558, 154, 269, 348, 385, 442, 176, 547, 326, 257, 193, 234, 486, 499]
a_sorted = sorted(a)

for el in a_sorted:
    if el % 2 == 0:
        b = el
        print(b)
        break
# Out:
# 118

# %%
min(a)
# Out:
# 101
