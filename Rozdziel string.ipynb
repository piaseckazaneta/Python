# %% [markdown]
# <a href="https://colab.research.google.com/github/piaseckazaneta/Python/blob/main/Rozdziel%20string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "23-ok-eee"

def split_string(text):
  text_split = text.split("-")
  for el in text_split:
    if el.isdigit():
       text_split[text_split.index(el)] = int(el)
       text_split = list(filter(None, text_split))
  return text_split
  print(text_split)


print(split_string(text))
# Out:
# [23, 'ok', 'eee']

# %%
# Inne rozwiązanie

def split_string(text):
    result = []
    for el in text.split("-"):
        if el.isdigit():
            result.append(int(el))
        elif el:  # pomija puste stringi
            result.append(el)
    return result




# elif el: to skrót od elif el != "" - Python sprawdza True/False, pusty string jest False
